# %%
from PIL import Image
import os

# 指定目标大小
target_size = (128, 128)

# 指定文件夹路径
folder_path = "./insulting/"
folder_path2 = "./insulting2/"
# 遍历文件夹中所有文件
for filename in os.listdir(folder_path):
    filepath = os.path.join(folder_path, filename)
    filepath2 = os.path.join(folder_path2, filename)
    print(filename)
    # 判断是否为图片文件
    if filepath.endswith(".jpg"):
        print('k')
        # 打开图片
        with Image.open(filepath) as img:
            # 调整大小
            if img.mode == "P":
                img = img.convert('RGB')
            resized_img = img.resize(target_size)
            # 保存修改后的图片
            resized_img.save(filepath2)
# Out:
# 102.jpg
# k
# 103.jpg
# k
# 104.jpg
# k
# 110.jpg
# k
# 115.jpg
# k
# 130.jpg
# k
# 131.jpg
# k
# 149.jpg
# k
# 151.jpg
# k
# 156.jpg
# k
# 158.jpg
# k
# 177.jpg
# k
# 195.jpg
# k
# 196.jpg
# k
# 198.jpg
# k
# 204.jpg
# k
# 209.jpg
# k
# 25.jpg
# k
# 253.jpg
# k
# 46.jpg
# k
# 67.jpg
# k
# 73.jpg
# k
# 78.jpg
# k
# 80.jpg
# k
# 81.jpg
# k
# 82.jpg
# k
# 84.jpg
# k
# 89.jpg
# k
# 92.jpg
# k
# 94.jpg
# k
# 96.jpg
# k
# data_config.ipynb

# %%
from PIL import Image
import os

# 指定目标大小
target_size = (128, 128)

# 指定文件夹路径
folder_path = "./uninsulting/"
folder_path2 = "./uninsulting2/"
# 遍历文件夹中所有文件
for filename in os.listdir(folder_path):
    filepath = os.path.join(folder_path, filename)
    filepath2 = os.path.join(folder_path2, filename)
    print(filename)
    # 判断是否为图片文件
    if filepath.endswith(".jpg"):
        print('k')
        # 打开图片
        with Image.open(filepath) as img:
            # 调整大小
            if img.mode == "P":
                img = img.convert('RGB')
            resized_img = img.resize(target_size)
            # 保存修改后的图片
            resized_img.save(filepath2)
# Out:
# 100.jpg
# k
# 101.jpg
# k
# 105.jpg
# k
# 106.jpg
# k
# 107.jpg
# k
# 108.jpg
# k
# 109.jpg
# k
# 111.jpg
# k
# 112.jpg
# k
# 113.jpg
# k
# 114.jpg
# k
# 116.jpg
# k
# 117.jpg
# k
# 118.jpg
# k
# 119.jpg
# k
# 120.jpg
# k
# 122.jpg
# k
# 123.jpg
# k
# 124.jpg
# k
# 125.jpg
# k
# 126.jpg
# k
# 128.jpg
# k
# 129.jpg
# k
# 132.jpg
# k
# 133.jpg
# k
# 134.jpg
# k
# 135.jpg
# k
# 136.jpg
# k
# 137.jpg
# k
# 138.jpg
# k
# 139.jpg
# k
# 14.jpg
# k
# 140.jpg
# k
# 141.jpg
# k
# 142.jpg
# k
# 143.jpg
# k
# 144.jpg
# k
# 145.jpg
# k
# 146.jpg
# k
# 147.jpg
# k
# 148.jpg
# k
# 150.jpg
# k
# 152.jpg
# k
# 153.jpg
# k
# 154.jpg
# k
# 155.jpg
# k
# 157.jpg
# k
# 159.jpg
# k
# 160.jpg
# k
# 161.jpg
# k
# 162.jpg
# k
# 163.jpg
# k
# 164.jpg
# k
# 165.jpg
